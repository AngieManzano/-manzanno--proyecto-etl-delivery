# %% [markdown]
# <a href="https://colab.research.google.com/github/AngieManzano/-manzanno--proyecto-etl-delivery/blob/main/%5Bmanzano_proyecto_etl_delivery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🚀 EXTRACT
# Parte 1 - Extracción y Diagnóstico (Extract)

# %%
import pandas as pd
import numpy as np

# %%
# !pip install pandas

# %%
#En el colab
restaurantes = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurants.csv/restaurants.csv"
#Leer el archivo
df_restaurantes = pd.read_csv(restaurantes, sep=",")
display(df_restaurantes)
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 63464  63465         2                           IHOP (4321 N 10th St)    4.6
# 63465  63466        29                       Feldman's - N 10th Street    NaN
# 63466  63467        27                           Feldman's - N 23rd St    NaN
# 63467  63468        19           Church's Chicken (620 S. 10th Street)    4.3
# 63468  63469         9                       7-Eleven (1600 S 23rd St)    NaN
#
# ...

# %%
#En el colab
menu_1 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_1.csv"
#Leer el archivo
df_menu_1 = pd.read_csv(menu_1, sep=",")
display(df_menu_1)
# Out:
#        restaurant_id           category  \
# 0                  1  Extra Large Pizza
# 1                  1  Extra Large Pizza
# 2                  1  Extra Large Pizza
# 3                  1  Extra Large Pizza
# 4                  1  Extra Large Pizza
# ...              ...                ...
# 83630           1138         Sandwiches
# 83631           1138         Sandwiches
# 83632           1138         Sandwiches
# 83633           1138         Sandwiches
# 83634           1138         Sandwiches
#
#                                         name  \
# 0                    Extra Large Meat Lovers
# 1                        Extra Large Supreme
# 2                      Extra Large Pepperoni
# 3        Extra Large BBQ Chicken &amp; Bacon
# 4                       Extra Large 5 Cheese
# ...                                      ...
# 83630           Portabella Mushroom Sandwich
# 83631  Grilled Chicken Italian Club Sandwich
# 83632               Chicken Caprese Sandwich
# ...

# %%
#En el colab
menu_2 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_2.csv"
#Leer el archivo
df_menu_2 = pd.read_csv(menu_2, sep=",")
display(df_menu_2)
# Out:
#        restaurant_id    category                        name  \
# 0               1138  Sandwiches    Filet of Salmon Sandwich
# 1               1138     Burgers                   Hamburger
# 2               1138     Burgers              Buffalo Burger
# 3               1138     Burgers                Cheeseburger
# 4               1138     Burgers  Applewood Bacon BBQ Burger
# ...              ...         ...                         ...
# 83630           2295     Entrees             Pud Num Mun Hoy
# 83631           2295     Entrees            Pud Pug Ruam Mit
# 83632           2295     Entrees         Bangkok Connections
# 83633           2295     Entrees              Pud Prig Khing
# 83634           2295     Entrees               Pud Prew Warn
#
#                                              description      price
# 0      Comes with your choice of french fries, fresh ...   13.0 USD
# 1      Hamburgers are one-half pound served medium on...    9.0 USD
# ...

# %%
#En el colab
menu_3 = "https://github.com/IanCN-23/dalatam_ed3_TPI_Python/raw/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_3.csv"
#Leer el archivo
df_menu_3 = pd.read_csv(menu_3, sep=",")
display(df_menu_3)
# Out:
#        restaurant_id                   category  \
# 0               2295                    Entrees
# 1               2295                    Entrees
# 2               2295                    Entrees
# 3               2295                    Seafood
# 4               2295                    Seafood
# ...              ...                        ...
# 83630           3237                    Fajitas
# 83631           3237                    Fajitas
# 83632           3237  Salads, Soups &amp; Chili
# 83633           3237  Salads, Soups &amp; Chili
# 83634           3237  Salads, Soups &amp; Chili
#
#                                                  name  \
# 0                                        Pud Prig Sod
# 1                                        Pud Prig Pow
# 2                                       Bangkok Steak
# 3                             Plah Lad Prig (Snapper)
# 4                               Tamarind Mango Shrimp
# ...                                               ...
# ...

# %%
#En el colab
menu_4 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_4.csv"
#Leer el archivo
df_menu_4 = pd.read_csv(menu_4, sep=",")
display(df_menu_4)
# Out:
#        restaurant_id                   category  \
# 0               3237  Salads, Soups &amp; Chili
# 1               3237  Salads, Soups &amp; Chili
# 2               3237  Salads, Soups &amp; Chili
# 3               3237  Salads, Soups &amp; Chili
# 4               3237  Salads, Soups &amp; Chili
# ...              ...                        ...
# 83630           4208                Lunch Mains
# 83631           4208                Lunch Mains
# 83632           4208                Lunch Mains
# 83633           4208           Lunch Sandwiches
# 83634           4208           Lunch Sandwiches
#
#                                        name  \
# 0                    Santa Fe Chicken Salad
# 1        Caribbean Salad with Seared Shrimp
# 2      Caribbean Salad with Grilled Chicken
# 3            Southwest Chicken Caesar Salad
# 4             Southwest Shrimp Caesar Salad
# ...                                     ...
# 83630                    Pan-Roasted Salmon
# ...

# %%
#En el colab
menu_5 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_5.csv"
#Leer el archivo
df_menu_5 = pd.read_csv(menu_5, sep=",")
display(df_menu_5)
# Out:
#        restaurant_id          category  \
# 0               4208  Lunch Sandwiches
# 1               4208  Lunch Sandwiches
# 2               4208      Lunch Salads
# 3               4208      Lunch Salads
# 4               4208      Lunch Salads
# ...              ...               ...
# 83630           5177          Burritos
# 83631           5177          Burritos
# 83632           5177          Burritos
# 83633           5177          Burritos
# 83634           5177          Burritos
#
#                                          name  \
# 0                            BLT Cheeseburger
# 1                         Thai Short Rib Wrap
# 2                               Burrata Salad
# 3                 Brussel Sprout Caeser Salad
# 4                              Classic Caesar
# ...                                       ...
# 83630                        Burrito Supreme®
# 83631  Chipotle Ranch Grilled Chicken Burrito
# 83632                      Beefy Melt Burrito
# ...

# %%
#En el colab
menu_6 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_6.csv"
#Leer el archivo
df_menu_6 = pd.read_csv(menu_6, sep=",")
display(df_menu_6)
# Out:
#        restaurant_id     category                                  name  \
# 0               5177     Burritos                  Chili Cheese Burrito
# 1               5177  Quesadillas                    Chicken Quesadilla
# 2               5177  Quesadillas                      Steak Quesadilla
# 3               5177  Quesadillas                     Cheese Quesadilla
# 4               5177       Nachos                    Nachos BellGrande®
# ...              ...          ...                                   ...
# 83630           6052   Candy Bars            MARS TWIX CRML KING Single
# 83631           6052   Candy Bars  BUTTERFINGER KING SHARE 3.7OZ Single
# 83632           6052        Chips  COMBOS 6.3OZ PIZZERIA PRETZEL Single
# 83633           6052        Chips   COMBOS 6.3OZ PEPP PIZZA CRKR Single
# 83634           6052        Chips   COMBOS 6.3OZ CHED CHSE PRZTL Single
#
#                                              description     price
# ...

# %%
#En el colab
menu_7 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_7.csv"
#Leer el archivo
df_menu_7 = pd.read_csv(menu_7, sep=",")
display(df_menu_7)
# Out:
#        restaurant_id       category  \
# 0               6052          Chips
# 1               6052          Chips
# 2               6052          Chips
# 3               6052          Chips
# 4               6052          Chips
# ...              ...            ...
# 83630           6886  Personal Care
# 83631           6886  Sexual Health
# 83632           6886  Sexual Health
# 83633           6886  Sexual Health
# 83634           6886  Sexual Health
#
#                                                     name  \
# 0                           FRITO TOSTITOS SCOOPS Single
# 1                        ANDY CAPP HOT FRIES 3 OZ Single
# 2                              CHEETOS CRUNCHY XL Single
# 3                        DORITO 9.75OZ COOL RANCH Single
# 4                             DORITO 9.75OZ NACHO Single
# ...                                                  ...
# 83630  Dove Antiperspirant Deodorant Dry Spray 3.8 OZ...
# 83631                       Trojan Bareskin Condoms, 3ct
# ...

# %%
#En el colab
menu_8 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_8.csv"
#Leer el archivo
df_menu_8 = pd.read_csv(menu_8, sep=",")
display(df_menu_8)
# Out:
#        restaurant_id                                           category  \
# 0               6886                                      Sexual Health
# 1               6886                                      Sexual Health
# 2               6886                                      Sexual Health
# 3               6886                                      Sexual Health
# 4               6886                                      Sexual Health
# ...              ...                                                ...
# 83630           7810  Build Your Own Pizza (Sauce &amp; Mozzarella i...
# 83631           7810  Build Your Own Pizza (Sauce &amp; Mozzarella i...
# 83632           7810  Build Your Own Pizza (Sauce &amp; Mozzarella i...
# 83633           7810  Build Your Own Pizza (Sauce &amp; Mozzarella i...
# 83634           7810  Build Your Own Pizza (Sauce &amp; Mozzarella i...
#
#                                                     name  \
# ...

# %%
#En el colab
menu_9 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_9.csv"



valores_basura = ["???", "No_Data"]


#Leer el archivo
df_menu_9 = pd.read_csv(menu_9, sep=",",
    na_values=valores_basura)
display(df_menu_9)
# Out:
#        restaurant_id                                           category  \
# 0               7810  Pizza By The Slice (6" hot sandwich if we run ...
# 1               7810  Pizza By The Slice (6" hot sandwich if we run ...
# 2               7810  Pizza By The Slice (6" hot sandwich if we run ...
# 3               7810                              Create Your Own Pasta
# 4               7810                        French Bread Hot Sandwiches
# ...              ...                                                ...
# 83630           8984                                         Sandwiches
# 83631           8984                                         Sandwiches
# 83632           8984                                         Sandwiches
# 83633           8984                                         Sandwiches
# 83634           8984                                         Sandwiches
#
#                                                     name  \
# ...

# %%
#En el colab
menu_10 = "https://raw.githubusercontent.com/IanCN-23/dalatam_ed3_TPI_Python/refs/heads/main/restaurant-menus.csv/restaurant_menus_parte_10.csv"

valores_basura = ["???", "No_Data"]


#Leer el archivo
df_menu_10 = pd.read_csv(menu_10, sep=",",
    na_values=valores_basura)
display(df_menu_10)
# Out:
#        restaurant_id          category  \
# 0               8984        Sandwiches
# 1               8984        Sandwiches
# 2               8984        Sandwiches
# 3               8984        Sandwiches
# 4               8984        Sandwiches
# ...              ...               ...
# 83630          10082  Individual Items
# 83631          10082  Individual Items
# 83632          10082  Individual Items
# 83633          10082  Individual Items
# 83634          10082  Individual Items
#
#                                                  name  \
# 0                 Black Forest Ham 6 Inch Regular Sub
# 1               Black Forest Ham Footlong Regular Sub
# 2      Black Forest Ham Footlong Pro (Double Protein)
# 3                  Buffalo Chicken 6 Inch Regular Sub
# 4                Buffalo Chicken Footlong Regular Sub
# ...                                               ...
# 83630                             Triple Cheeseburger
# ...

# %%
df_menus = pd.concat([df_menu_1,df_menu_2,df_menu_3,df_menu_4,df_menu_5,df_menu_6,df_menu_7,df_menu_8,df_menu_9,df_menu_10], ignore_index=True)

# %%
df_menus
# Out:
#         restaurant_id           category                                 name  \
# 0                   1  Extra Large Pizza              Extra Large Meat Lovers
# 1                   1  Extra Large Pizza                  Extra Large Supreme
# 2                   1  Extra Large Pizza                Extra Large Pepperoni
# 3                   1  Extra Large Pizza  Extra Large BBQ Chicken &amp; Bacon
# 4                   1  Extra Large Pizza                 Extra Large 5 Cheese
# ...               ...                ...                                  ...
# 836345          10082   Individual Items                  Triple Cheeseburger
# 836346          10082   Individual Items                             McDouble
# 836347          10082   Individual Items   Quarter Pounder with Cheese Deluxe
# 836348          10082   Individual Items                       Bacon McDouble
# 836349          10082   Individual Items                    4 Piece McNuggets
#
#        description      price
# ...

# %%
df_restaurantes.shape
# Out:
# (63469, 11)

# %%
df_menus.shape
# Out:
# (836350, 5)

# %%
df_restaurantes.columns
# Out:
# Index(['id', 'position', 'name', 'score', 'ratings', 'category', 'price_range',
#        'full_address', 'zip_code', 'lat', 'lng'],
#       dtype='object')

# %%
df_menus.columns
# Out:
# Index(['restaurant_id', 'category', 'name', 'description', 'price'], dtype='object')

# %%
df_restaurantes.index
# Out:
# RangeIndex(start=0, stop=63469, step=1)

# %%
df_menus.index
# Out:
# RangeIndex(start=0, stop=836350, step=1)

# %%
type(df_restaurantes['name'])
# Out:
# pandas.core.series.Series

# %%
df_restaurantes.dtypes
# Out:
# id                int64
# position          int64
# name             object
# score           float64
# ratings         float64
# category         object
# price_range      object
# full_address     object
# zip_code         object
# lat             float64
# lng             float64
# dtype: object

# %%
df_restaurantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63469 entries, 0 to 63468
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            63469 non-null  int64
#  1   position      63469 non-null  int64
#  2   name          63469 non-null  object
#  3   score         35302 non-null  float64
#  4   ratings       35302 non-null  float64
#  5   category      63384 non-null  object
#  6   price_range   52852 non-null  object
#  7   full_address  63016 non-null  object
#  8   zip_code      62952 non-null  object
#  9   lat           63469 non-null  float64
#  10  lng           63469 non-null  float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 5.3+ MB

# %%
df_restaurantes.isnull()
# Out:
#           id  position   name  score  ratings  category  price_range  \
# 0      False     False  False   True     True     False        False
# 1      False     False  False   True     True     False         True
# 2      False     False  False   True     True     False        False
# 3      False     False  False   True     True     False        False
# 4      False     False  False  False    False     False         True
# ...      ...       ...    ...    ...      ...       ...          ...
# 63464  False     False  False  False    False     False        False
# 63465  False     False  False   True     True      True         True
# 63466  False     False  False   True     True      True         True
# 63467  False     False  False  False    False     False        False
# 63468  False     False  False   True     True     False        False
#
#        full_address  zip_code    lat    lng
# 0             False     False  False  False
# 1             False     False  False  False
# ...

# %%
df_restaurantes.isna()
# Out:
#           id  position   name  score  ratings  category  price_range  \
# 0      False     False  False   True     True     False        False
# 1      False     False  False   True     True     False         True
# 2      False     False  False   True     True     False        False
# 3      False     False  False   True     True     False        False
# 4      False     False  False  False    False     False         True
# ...      ...       ...    ...    ...      ...       ...          ...
# 63464  False     False  False  False    False     False        False
# 63465  False     False  False   True     True      True         True
# 63466  False     False  False   True     True      True         True
# 63467  False     False  False  False    False     False        False
# 63468  False     False  False   True     True     False        False
#
#        full_address  zip_code    lat    lng
# 0             False     False  False  False
# 1             False     False  False  False
# ...

# %%
df_menus.isna()
# Out:
#         restaurant_id  category   name  description  price
# 0               False     False  False        False  False
# 1               False     False  False        False  False
# 2               False     False  False        False  False
# 3               False     False  False        False  False
# 4               False     False  False        False  False
# ...               ...       ...    ...          ...    ...
# 836345          False     False  False         True  False
# 836346          False     False  False         True  False
# 836347          False     False  False         True  False
# 836348          False     False  False         True  False
# 836349          False     False  False         True  False
#
# [836350 rows x 5 columns]

# %%
df_menus.dtypes
# Out:
# restaurant_id     int64
# category         object
# name             object
# description      object
# price            object
# dtype: object

# %%
print(df_restaurantes.isnull().sum())
# Out:
# id                  0
# position            0
# name                0
# score           28167
# ratings         28167
# category           85
# price_range     10617
# full_address      453
# zip_code          517
# lat                 0
# lng                 0
# dtype: int64

# %% [markdown]
# 🚀 Transform
# Parte 2 - Ingeniería de Características y Limpieza (Transform)

# %%
diccionario_precios = {
    '$': "Economico",
    '$$': "Moderadamente caro",
    '$$$': "Caro",
    '$$$$': "Muy caro",
    '$$$$$$$$$$$$$$$$$': "Extremadamente caro"
}

print(diccionario_precios)
# Out:
# {'$': 'Economico', '$$': 'Moderadamente caro', '$$$': 'Caro', '$$$$': 'Muy caro', '$$$$$$$$$$$$$$$$$': 'Extremadamente caro'}

# %%
df_restaurantes['price_range'] = df_restaurantes['price_range'].replace(diccionario_precios)
display(df_restaurantes)
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 63464  63465         2                           IHOP (4321 N 10th St)    4.6
# 63465  63466        29                       Feldman's - N 10th Street    NaN
# 63466  63467        27                           Feldman's - N 23rd St    NaN
# 63467  63468        19           Church's Chicken (620 S. 10th Street)    4.3
# 63468  63469         9                       7-Eleven (1600 S 23rd St)    NaN
#
# ...

# %%
print(df_restaurantes['price_range'].unique())
# Out:
# ['Economico' nan 'Moderadamente caro' 'Caro' 'Muy caro'
#  'Extremadamente caro']

# %%
display(df_restaurantes)
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 63464  63465         2                           IHOP (4321 N 10th St)    4.6
# 63465  63466        29                       Feldman's - N 10th Street    NaN
# 63466  63467        27                           Feldman's - N 23rd St    NaN
# 63467  63468        19           Church's Chicken (620 S. 10th Street)    4.3
# 63468  63469         9                       7-Eleven (1600 S 23rd St)    NaN
#
# ...

# %% [markdown]
# Desanidado de Ubicaciones

# %%
df_separado= df_restaurantes['full_address'].str.split(',', n=2, expand=True)

df_restaurantes['calle'] = df_separado[0]
df_restaurantes['ciudad'] = df_separado[1]
df_restaurantes['estado_zip'] = df_separado[2]


df_restaurantes['ciudad'] = df_restaurantes['ciudad'].str.strip()

# %%
display(df_restaurantes)
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 63464  63465         2                           IHOP (4321 N 10th St)    4.6
# 63465  63466        29                       Feldman's - N 10th Street    NaN
# 63466  63467        27                           Feldman's - N 23rd St    NaN
# 63467  63468        19           Church's Chicken (620 S. 10th Street)    4.3
# 63468  63469         9                       7-Eleven (1600 S 23rd St)    NaN
#
# ...

# %% [markdown]
# Filtro de Calidad

# %%
df_restaurantes = df_restaurantes[df_restaurantes['ratings'].notnull() & (df_restaurantes['ratings'] != 0)].copy()
df_restaurantes = df_restaurantes[df_restaurantes['score'].notnull() & (df_restaurantes['score'] != 0)].copy()


df_restaurantes['category'] = df_restaurantes['category'].str.lower()

# %%
display(df_restaurantes)
# Out:
#           id  position                                      name  score  \
# 4          5       162          Nelson Brothers Cafe (17th St N)    4.7
# 6          7        27                              Jinsei Sushi    4.7
# 13        14        51              Panera (521 Fieldstown Road)    4.6
# 15        16        88  Jeni's Splendid Ice Cream (Pepper Place)    5.0
# 18        19        30                              Falafel Cafe    4.9
# ...      ...       ...                                       ...    ...
# 63448  63449         9              Walgreens (701 E NOLANA AVE)    4.8
# 63460  63461       114              Cosmic Wings (Mcallen North)    4.4
# 63462  63463        41              Whataburger (4017 N 23rd St)    5.0
# 63464  63465         2                     IHOP (4321 N 10th St)    4.6
# 63467  63468        19     Church's Chicken (620 S. 10th Street)    4.3
#
#        ratings                                           category  \
# ...

# %% [markdown]
# En df_menus:

# %%
display(df_menus)
# Out:
#         restaurant_id           category                                 name  \
# 0                   1  Extra Large Pizza              Extra Large Meat Lovers
# 1                   1  Extra Large Pizza                  Extra Large Supreme
# 2                   1  Extra Large Pizza                Extra Large Pepperoni
# 3                   1  Extra Large Pizza  Extra Large BBQ Chicken &amp; Bacon
# 4                   1  Extra Large Pizza                 Extra Large 5 Cheese
# ...               ...                ...                                  ...
# 836345          10082   Individual Items                  Triple Cheeseburger
# 836346          10082   Individual Items                             McDouble
# 836347          10082   Individual Items   Quarter Pounder with Cheese Deluxe
# 836348          10082   Individual Items                       Bacon McDouble
# 836349          10082   Individual Items                    4 Piece McNuggets
#
#        description      price
# ...

# %%
df_menus['price'] = df_menus['price'].str.replace(' USD', '', regex=False) \
                         .str.replace(',', '.', regex=False) \
                         .astype(float)

# %%
display(df_menus)
# Out:
#         restaurant_id           category                                 name  \
# 0                   1  Extra Large Pizza              Extra Large Meat Lovers
# 1                   1  Extra Large Pizza                  Extra Large Supreme
# 2                   1  Extra Large Pizza                Extra Large Pepperoni
# 3                   1  Extra Large Pizza  Extra Large BBQ Chicken &amp; Bacon
# 4                   1  Extra Large Pizza                 Extra Large 5 Cheese
# ...               ...                ...                                  ...
# 836345          10082   Individual Items                  Triple Cheeseburger
# 836346          10082   Individual Items                             McDouble
# 836347          10082   Individual Items   Quarter Pounder with Cheese Deluxe
# 836348          10082   Individual Items                       Bacon McDouble
# 836349          10082   Individual Items                    4 Piece McNuggets
#
#        description  price
# ...

# %%
df_menus_= df_menus[df_menus['price'].notnull() & (df_menus['price'] != 0.0)].copy()

# %%
display(df_menus)
# Out:
#         restaurant_id           category                                 name  \
# 0                   1  Extra Large Pizza              Extra Large Meat Lovers
# 1                   1  Extra Large Pizza                  Extra Large Supreme
# 2                   1  Extra Large Pizza                Extra Large Pepperoni
# 3                   1  Extra Large Pizza  Extra Large BBQ Chicken &amp; Bacon
# 4                   1  Extra Large Pizza                 Extra Large 5 Cheese
# ...               ...                ...                                  ...
# 836345          10082   Individual Items                  Triple Cheeseburger
# 836346          10082   Individual Items                             McDouble
# 836347          10082   Individual Items   Quarter Pounder with Cheese Deluxe
# 836348          10082   Individual Items                       Bacon McDouble
# 836349          10082   Individual Items                    4 Piece McNuggets
#
#        description  price
# ...

# %% [markdown]
# Optimización y Cruce (Control de Memoria RAM):

# %%
df_restaurantes = df_restaurantes[df_restaurantes['ratings'] > 100].copy()

# %%
display(df_restaurantes['ratings'])
# Out:
# 1738     200.0
# 1741     128.0
# 1774     115.0
# 1789     200.0
# 1794     107.0
#          ...
# 63346    179.0
# 63393    108.0
# 63408    200.0
# 63413    200.0
# 63426    200.0
# Name: ratings, Length: 8702, dtype: float64

# %%
display(df_menus)
# Out:
#         restaurant_id           category                                 name  \
# 0                   1  Extra Large Pizza              Extra Large Meat Lovers
# 1                   1  Extra Large Pizza                  Extra Large Supreme
# 2                   1  Extra Large Pizza                Extra Large Pepperoni
# 3                   1  Extra Large Pizza  Extra Large BBQ Chicken &amp; Bacon
# 4                   1  Extra Large Pizza                 Extra Large 5 Cheese
# ...               ...                ...                                  ...
# 836345          10082   Individual Items                  Triple Cheeseburger
# 836346          10082   Individual Items                             McDouble
# 836347          10082   Individual Items   Quarter Pounder with Cheese Deluxe
# 836348          10082   Individual Items                       Bacon McDouble
# 836349          10082   Individual Items                    4 Piece McNuggets
#
#        description  price
# ...

# %%
df_restaurantes.rename(columns={"id": "id_restaurantes"}, inplace=True)

# %%
df_menus.rename(columns={"restaurantes_id ": "id_menus"}, inplace=True)

# %%
df_master= pd.merge(
     df_restaurantes,
       df_menus,
    left_on= 'id_restaurantes',
    right_on= 'restaurant_id',
    suffixes= ('_restaurantes','_menus'),
     how='inner'

)
display(df_master)
# Out:
#        id_restaurantes  position  \
# 0                 1739        21
# 1                 1739        21
# 2                 1739        21
# 3                 1739        21
# 4                 1739        21
# ...                ...       ...
# 65763            10076        14
# 65764            10076        14
# 65765            10076        14
# 65766            10076        14
# 65767            10076        14
#
#                                        name_restaurantes  score  ratings  \
# 0                                  Pho Cali Noodle House    4.4    200.0
# 1                                  Pho Cali Noodle House    4.4    200.0
# 2                                  Pho Cali Noodle House    4.4    200.0
# 3                                  Pho Cali Noodle House    4.4    200.0
# 4                                  Pho Cali Noodle House    4.4    200.0
# ...                                                  ...    ...      ...
# ...

# %%
display(df_master['restaurant_id'])
# Out:
# 0         1739
# 1         1739
# 2         1739
# 3         1739
# 4         1739
#          ...
# 65763    10076
# 65764    10076
# 65765    10076
# 65766    10076
# 65767    10076
# Name: restaurant_id, Length: 65768, dtype: int64

# %%
df_master.to_csv('master.csv',index=False, sep=';' )

# %%
df_master.to_excel('master.xlsx')

# %%
df_master_exportado = pd.read_csv('master.csv', sep=';', low_memory=False)
print(df_master_exportado)
# Out:
#        id_restaurantes  position  \
# 0                 1739        21
# 1                 1739        21
# 2                 1739        21
# 3                 1739        21
# 4                 1739        21
# ...                ...       ...
# 65763            10076        14
# 65764            10076        14
# 65765            10076        14
# 65766            10076        14
# 65767            10076        14
#
#                                        name_restaurantes  score  ratings  \
# 0                                  Pho Cali Noodle House    4.4    200.0
# 1                                  Pho Cali Noodle House    4.4    200.0
# 2                                  Pho Cali Noodle House    4.4    200.0
# 3                                  Pho Cali Noodle House    4.4    200.0
# 4                                  Pho Cali Noodle House    4.4    200.0
# ...                                                  ...    ...      ...
# ...

# %% [markdown]
# 🔍Load
# Parte 3 - Carga a Base de Datos (Load)

# %%
from sqlalchemy import create_engine

motor_sql = create_engine('sqlite:///delivery_insights.db')

df_master.to_sql(name='master_food_data',
                      con = motor_sql,
                       if_exists= 'replace',
                       index = False)
# Out:
# 65768

# %%
from sqlalchemy import text

# %%
with motor_sql.connect() as conexion:
  tablas = pd.read_sql(text("""
    SELECT name
    FROM sqlite_master
    WHERE type = 'table'
  """), conexion)
  print(tablas)
# Out:
#                name
# 0  master_food_data

# %% [markdown]
# 📊 BI
# Parte 4 - Business Intelligence: Reporte al CEO (SQL + Visualización)

# %%
query= """
select * from master_food_data

"""

# %%
with motor_sql.connect() as conexion:
  query_output = pd.read_sql(text(query),conexion)
  print(query_output)
# Out:
#        id_restaurantes  position  \
# 0                 1739        21
# 1                 1739        21
# 2                 1739        21
# 3                 1739        21
# 4                 1739        21
# ...                ...       ...
# 65763            10076        14
# 65764            10076        14
# 65765            10076        14
# 65766            10076        14
# 65767            10076        14
#
#                                        name_restaurantes  score  ratings  \
# 0                                  Pho Cali Noodle House    4.4    200.0
# 1                                  Pho Cali Noodle House    4.4    200.0
# 2                                  Pho Cali Noodle House    4.4    200.0
# 3                                  Pho Cali Noodle House    4.4    200.0
# 4                                  Pho Cali Noodle House    4.4    200.0
# ...                                                  ...    ...      ...
# ...

# %% [markdown]
# 1. Penetración Geográfica: ¿Cuáles son las 5 ciudades (ciudad) con la mayor
# cantidad de restaurantes consolidados (los que quedaron en nuestra base)?

# %%
query_1 = """
SELECT
    ciudad,
    COUNT(DISTINCT id_restaurantes) AS cantidad_restaurantes
FROM master_food_data
WHERE ciudad IS NOT NULL
GROUP BY ciudad
ORDER BY cantidad_restaurantes DESC
LIMIT 5;
"""

# %%
with motor_sql.connect() as conn:
    df_top_ciudades = pd.read_sql(text(query_1), conn)
    print(df_top_ciudades)
# Out:
#       ciudad  cantidad_restaurantes
# 0  Milwaukee                    122
# 1    Seattle                    120
# 2   Lynnwood                     40
# 3    Everett                     32
# 4   Bellevue                     29

# %%
ax = sns.barplot(
    x='cantidad_restaurantes',
    y='ciudad',
    data=df_top_ciudades,

)

ax.bar_label(ax.containers[0], padding=3)
plt.title('Top 5 Ciudades con Mayor Cantidad de Restaurantes', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Cantidad de Restaurantes', fontsize=12)
plt.ylabel('Ciudad', fontsize=12)
plt.xlim(0, df_top_ciudades['cantidad_restaurantes'].max() * 1.15)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se encontró que las 5 ciudades con mayor cantidad de restaurantes consolidados son Milwaukee, Seattle, Lynnwood, Everett y Bellevue. Siendo Milwaukee el que tiene mayor cantidad de restaurantes.

# %% [markdown]
# 2. Análisis de Oportunidad de Precio: El CEO cree que todos los restaurantes en
# el mercado son caros. Usando los datos, muestre la distribución de la columna
# rango_de_precios a nivel general (¿Cuántos hay en "Económico", "Caro", etc.?).

# %%
query_2 = """
SELECT
    price_range,
    COUNT(DISTINCT 	id_restaurantes) AS total_restaurantes
FROM master_food_data
WHERE price_range IS NOT NULL
GROUP BY price_range
ORDER BY total_restaurantes DESC;
"""

# %%
with motor_sql.connect() as conn:
    cantidad_total_restaurantes = pd.read_sql(text(query_2), conn)
    print(cantidad_total_restaurantes)
# Out:
#           price_range  total_restaurantes
# 0           Economico                 452
# 1  Moderadamente caro                 159
# 2                Caro                   4

# %%
labels = cantidad_total_restaurantes['price_range']
valores = cantidad_total_restaurantes['total_restaurantes']
colores = sns.color_palette('pastel')[0:len(labels)]

plt.pie(
    valores,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    colors=colores,
    textprops={'fontsize': 11}
)

plt.axis('equal')


plt.title(
    'Análisis de Precio\nDistribución General por Rango de Precios',
    fontsize=14,
    fontweight='bold',
    pad=20
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Se encontró que en Economico hay 452, en Moderadamente caro hay 159 y en Caro hay 4.

# %% [markdown]
# 3. Estrategia de Menú por Ciudad: Para las 3 ciudades más populares obtenidas
# en la pregunta 1, calcule el precio promedio de los platos en el menú. ¿En
# qué ciudad es más caro comer en promedio?

# %%
query_3 = """
SELECT
    ciudad,
    ROUND(AVG(price), 2) AS precio_promedio
FROM master_food_data
WHERE ciudad IN ('Milwaukee', 'Seattle', 'Lynnwood')
GROUP BY ciudad
ORDER BY precio_promedio DESC;
"""

# %%
with motor_sql.connect() as conn:
    promedio_total_restaurantes_1 = pd.read_sql(text(query_3), conn)
    print(promedio_total_restaurantes_1)
# Out:
#       ciudad  precio_promedio
# 0    Seattle            11.90
# 1   Lynnwood            10.50
# 2  Milwaukee             9.06

# %%
sns.set_theme(style="whitegrid")
plt.figure()


ax = sns.barplot(
    x='ciudad',
    y='precio_promedio',
    data=promedio_total_restaurantes_1,
    palette='Oranges_r',
    hue='ciudad',
    legend=False
)
for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.2f} ",
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 9),
        textcoords='offset points',
        fontweight='bold'
    )


plt.title('Precio Promedio del Menú en las 3 Ciudades Principales', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('Ciudad', fontsize=12)
plt.ylabel('Precio Promedio por Plato', fontsize=12)
plt.ylim(0, promedio_total_restaurantes_1['precio_promedio'].max() * 1.15)

plt.tight_layout()
plt.show()

# %% [markdown]
# Se encontró que es más caro comer en Seattle porque tiene un precio promedio de 11.90.

# %% [markdown]
# 4. La Pregunta del Millón (Correlación Precio-Calidad): ¿Un restaurante más
# caro garantiza una mejor experiencia para el usuario? Escriba un query que
# calcule el puntaje (score) promedio agrupado por rango_de_precios. Utilice un
# gráfico de líneas o de barras para demostrar visualmente al CEO si la calidad
# sube a medida que aumenta la categoría de precio.

# %%
query_4 = """

SELECT
    price_range,
    ROUND(AVG(score), 2) AS score_promedio,
    COUNT(DISTINCT id_restaurantes) AS total_restaurantes
FROM  master_food_data
WHERE price_range IS NOT NULL AND score IS NOT NULL
GROUP BY  price_range
;
"""

# %%
with motor_sql.connect() as conn:
    promedio_restaurante_puntaje= pd.read_sql(text(query_4), conn)
    print(promedio_restaurante_puntaje)
# Out:
#           price_range  score_promedio  total_restaurantes
# 0                Caro            4.43                   4
# 1           Economico            4.61                 452
# 2  Moderadamente caro            4.61                 159

# %%
ax = sns.barplot(
    x='price_range',
    y='score_promedio',
    data=promedio_restaurante_puntaje,

)

for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.2f} ★",
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),
        textcoords='offset points',
        fontweight='bold',
        fontsize=11
    )

plt.title('Score Promedio por Rango de Precios', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('Categoría de Precio', fontsize=12)
plt.ylabel('Puntaje Promedio', fontsize=12)


plt.ylim(0, 5.0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Se encontró que no necesariamente si el restauranante es más caro es mejor la experiencia para el ususario. Ya que la categoria de "Economico" supero en experiencia del usuario a la categoria de "Caro". La categoria de "Economico" y "Moderadamente caro" obtuvieron el mayor puntaje, haciendo que ambos sean los restaurantes con mejor experiencia de ususario.
